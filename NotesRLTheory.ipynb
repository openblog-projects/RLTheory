# %% [markdown]
# # Intro To Reinforcement Rearning

# %% [markdown]
# # General thouhgts on how to create the course

# %% [markdown]
# 1. ![IMG_DE17C3CB2DA5-1.jpeg](attachment:IMG_DE17C3CB2DA5-1.jpeg) --> use this as the first animation (but in black white), than zoom in RL and all headlines appear (also black and white)
# 1. create a view with all headlines about which i wanna talk about
#     - markov decision porcesses
#     - PPO
# 2. make a transform to in the first headline
# 3. List the 3 entities of the bulding blocks:
#     - Observations
#     - Reward
#     - Action

# %% [markdown]
# 4. Transform to the following image (instead of the brain the vaccum cleaner from the game) with colored letters![IMG_3F4A200D3088-1.jpeg](attachment:IMG_3F4A200D3088-1.jpeg)
#
#     1. First show Agent
#     2. show observation (in the background explain what each of this components are)
#     3. show reward
#     4. show action

# %% [markdown]
# 5. "With the sequence of obseravtions, actions and rewards an history is cerated" (create formula from following image $O_t, A_t, R_t$ under the image with the agent, color the letters to recognize better):
# ![IMG_ADA275E14177-1.jpeg](attachment:IMG_ADA275E14177-1.jpeg)

# %% [markdown]
# 6. "From the history we can derivative us the state" (here now the transform from the whole formula $H_t$ to the following image):
# ![IMG_1B3458DFACFE-1.jpeg](attachment:IMG_1B3458DFACFE-1.jpeg)

# %%
7. Now the jump to Markov

Understanding markov

# %%
**Notes**
I should include somehow the environment in the process

# %% [markdown]
# Building blocks of RL:
#     1. Reward
#     2. Goal: select acitons to maximise total future reward
#     3.

# %% [markdown]
# ### ML-Agents
#
# **Building blocks of RL:**
#
# ML agents specific creation of constant definition of three entities in environment is necessary:
#
# - Observations
#     - what the agent gets from the environment
# - Actions
#     - behaviors like moving
# - Reward signals
#     - scalar which shows the agent if its good or not what he is doing
#
# The process of learning behavior is called policy - a good policy is if the agent maps based on observations optimal actions
#
# **Reward signals:**
#
# Extrinsic reward = reward from environment and gets achieved if reaching some goal
#
# Intrinsic reward = outside of the environment

# %% [markdown]
# j![Screen%20Shot%202022-03-11%20at%2010.59.22%20AM.png](attachment:Screen%20Shot%202022-03-11%20at%2010.59.22%20AM.png)

# %% [markdown]
# ### Markov decision processes
#
# $S$ = state space (set off all available states)
#
# $P_0$ = distribution over all possible starting spaces
#
# $A$ = Action space (all possible actions which can be taken)
#
# $P$ = Transition function --> $p(S_{t+1}|a_t, S_t) =$ given two parameters as an input $(a_t, S_t)$ how likely is it to land in State $S_{t+1}$
#
# $R$ = Reward function --> $R(S_t, a_r, S_{t+1}) = r_t$ = takes three inputs as parameters which result in reward
#
# $S_t$ = State at an certain timestep
#
# $a_t$ = action at an certain timestep
#
# $S_{t+1}$ = The next State from the current State in this timestep

# %% [markdown]
# ### Policy
# Policy intuitevly:
#
#     - Policies figuring out which actions to take (is the agents behavior)
#
# $\pi$ --> stochastic policies
#
# $\pi_{\theta}{(S_t)}$ (what is the best decision which an agent can do at a certain State $t$?)
#
# $S_t$ = State
#
# $\theta$ = weights of the network (Policy is based on neural network)

# %% [markdown]
# # Proximinal Policy Optimization (PPO)

# %% [markdown]
# ML agents provided two RL algos - PPO is the one which we use in the game, so description of him

# %% [markdown]
# $L^{CLIP}(\theta)=\hat{\mathop{\mathbb{E}}}_t \left[\min(r_t(\theta)\hat{A_t}, \text{clip}(r_t(\theta), 1-\epsilon, 1+\epsilon)\hat{A}_t)\right]$

# %% [markdown]
# $r_t(\theta) = \left[\frac{\pi_
# {\theta(a_t|S_t)}}{\pi_{\theta_{old}(a_t|S_t)}}\right]$ --> This does mean that the ratio between the new policy and the old policy gets computed.

# %% [markdown]
# $\hat{A}_t$ = Advantages --> how much better a certain action is than the actual policy function (whatever we actually doing in the environment as supposed to which policy we could do)

# %% [markdown]
# $\hat{\mathop{\mathbb{E}}}_t$

# %% [markdown]
# 1. $L^{CLIP}(\theta)=$ the annotation of the clip function whith the value of the policy loss
#
# 2. $\hat{\mathop{\mathbb{E}}}_t =$ weighted average of all possible outcomes for timestep $t$ https://en.wikipedia.org/wiki/Expected_value (dann muss es ja mehrere values als ergebnis wenn der average gebildet wird)
#
# 3. $\min=$ smallest value of the function https://en.wikipedia.org/wiki/Maxima_and_minima
#
# 4. $r_t(\theta)=$ration between the probability of action under current policy divided by previous one.
#
# 5. $\hat{A_t}=$ what is the advantage for choosing a certain action from a certain state
#
# 6. $\text{clip}=$

# %% [markdown]
# $\frac{\pi_
# {\theta(a_t|S_t)}}{\pi_{\theta_{old}(a_t|S_t)}}$
